# %% [markdown]
# # **Investment and saving analysis**
# ## **Level - 1**

# %% [markdown]
# ### **Step- 1 Importing Required Liabraries**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Step- 2 Load the Dataset**

# %%
df = pd.read_csv('Investment and saving data.csv')
df.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %% [markdown]
# ### **Step - 3 Performing The Descriptive analysis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %% [markdown]
# #### **Identifying the null value**

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### **Identifying the duplicate value**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### **Identify summary of statistics for numerical or categorical columns**

# %%
df.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %% [markdown]
# ### **Step-5 Identify and Vizualise the gender distribution**

# %%
plt.figure(figsize = (4,4))
ax = sns.countplot(x = 'gender', data=df)

ax.bar_label(ax.containers[0])
plt.title("gender distribution")
plt.show()

# %% [markdown]
# ## **Project Report: Investment and Saving Analysis (Level 1)**
# ### **Objective:**
# #### To perform an initial analysis of the dataset, explore its structure, and visualize key distributions.
#
# #### Steps Performed:
# #### **Step 1:** Data Loading
# ##### (i) The dataset was loaded successfully into a pandas DataFrame.
# ##### (ii) Key characteristics such as column names, data types, and a snapshot of the data were reviewed.
# #### **Step 2:** Dataset Overview
# ##### (i)Descriptive statistics were computed to summarize numerical columns, providing insights into measures
# #### **Step 3:** Null and Duplicate Check
# ##### **Null Values:**
# ##### (i)The dataset was checked for missing values column-wise.
# ##### (ii)No null column was identified
# ##### **Duplicate Rows:**
# #### (i)The dataset was checked for duplicate rows to ensure data integrity.
# #### (ii)No Duplicate column was identified
# #### **Step 4:** Dataset Overview
# #### (i)Descriptive statistics were computed to summarize numerical columns, providing insights into measures like count, mean, standard deviation, min, and max values.
# #### **Step 5:** Gender Distribution Visualization
# ##### (i)The distribution of genders was analyzed using a bar chart.
# ##### (ii)A bar chart was generated using Python libraries (matplotlib and seaborn).
# ##### (iii)The plot illustrates the number of males and females present in the dataset:
# ##### **Males: 25**
# ##### **Females: 15**
#
# ### **Conclusion:**
# #### The analysis provides a foundational understanding of the dataset's structure, investment patterns, and demographics:
#
# ##### (i)The dataset is clean, with no null or duplicate values.
# ##### (ii)Investment avenues like Mutual Funds and Fixed Deposits are popular among respondents.
# ##### (iii)A gender imbalance exists, favoring males.
